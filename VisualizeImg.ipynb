# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
import time

image_ids = ["003", "018", "036", "043", "038", "056", "067", "074"]
start = time.time()
test_image(image_ids[2])
print(time.time() - start)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-c1bf385012fe> in <module>
#       7 image_ids = ["003", "018", "036", "043", "038", "056", "067", "074"]
#       8 start = time.time()
# ----> 9 test_image(image_ids[2])
#      10 print(time.time() - start)
#
# ~/Desktop/CS4243/CS4243-Project/utils.py in test_image(image_id)
#      72     img = mpimg.imread(join("datasets/JPEGImages/{}.jpg".format(image_id)))
#      73     waldo_body_cascade = cv2.CascadeClassifier("waldo_body_0.3_0.0002.xml")
# ---> 74     waldo_bodies = waldo_body_cascade.detectMultiScale(img, 1.1, 9)
#      75     del img
#      76
#
# ...
